# %%
import pandas as pd

# %%
file_path = "spam.csv"  # Use your downloaded dataset file path
df = pd.read_csv(file_path, encoding="latin1")

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
import spacy
nlp=spacy.load('en_core_web_sm')

# %%
import pandas as pd
import spacy

# Load dataset
df = pd.read_csv(file_path, encoding="latin1")

# Load spaCy English model
# If not installed: python -m spacy download en_core_web_sm
nlp = spacy.load("en_core_web_sm")

# Function to process text using spaCy
def process_text_spacy(text):
    doc = nlp(text)  # Process the text
    
    # Tokens
    word_tokens = [token.text for token in doc]
    
    # Filtered tokens (remove stopwords and punctuation)
    filtered_tokens = [token.text for token in doc if not token.is_stop and not token.is_punct]
    
    # Lemmatized tokens (lowercase, remove stopwords and punctuation)
    lemmatized_tokens = [token.lemma_.lower() for token in doc if not token.is_stop and not token.is_punct]
    
    # POS tags
    pos_tags = [(token.text, token.pos_) for token in doc]
    
    # Named Entities
    named_entities = [(ent.text, ent.label_) for ent in doc.ents]
    
    return {
        "Original_Text": text,
        "Word_Tokens": word_tokens,
        "Filtered_Tokens": filtered_tokens,
        "Lemmatized_Tokens": lemmatized_tokens,
        "POS_Tags": pos_tags,
        "Named_Entities": named_entities
    }

# Apply processing
results = df["v2"].apply(process_text_spacy)

# Convert results to DataFrame
processed_df = pd.DataFrame(results.tolist())

# Display processed DataFrame
print(processed_df.head())

# Save processed results to CSV
processed_filepath = "processed_nlp_dataset_spacy_full.csv"
processed_df.to_csv(processed_filepath, index=False)
print(f"Processed dataset saved to {processed_filepath}")
# Out:
#                                        Original_Text  \
# 0  Go until jurong point, crazy.. Available only ...
# 1                      Ok lar... Joking wif u oni...
# 2  Free entry in 2 a wkly comp to win FA Cup fina...
# 3  U dun say so early hor... U c already then say...
# 4  Nah I don't think he goes to usf, he lives aro...
#
#                                          Word_Tokens  \
# 0  [Go, until, jurong, point, ,, crazy, .., Avail...
# 1           [Ok, lar, ..., Joking, wif, u, oni, ...]
# 2  [Free, entry, in, 2, a, wkly, comp, to, win, F...
# 3  [U, dun, say, so, early, hor, ..., U, c, alrea...
# 4  [Nah, I, do, n't, think, he, goes, to, usf, ,,...
#
#                                      Filtered_Tokens  \
# 0  [jurong, point, crazy, Available, bugis, n, gr...
# 1                     [Ok, lar, Joking, wif, u, oni]
# 2  [Free, entry, 2, wkly, comp, win, FA, Cup, fin...
# 3                         [U, dun, early, hor, U, c]
# ...
